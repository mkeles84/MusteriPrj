# %% [markdown]
# <a href="https://colab.research.google.com/github/mkeles84/MusteriPrj/blob/master/ColabvsGDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files

uploaded = files.upload()

# Assuming you upload only one file, get its name
if uploaded:
    uploaded_file_name = list(uploaded.keys())[0]
    print(f"'{uploaded_file_name}' dosyası Colab'a yüklendi.")
else:
    uploaded_file_name = None
    print("Hiçbir dosya yüklenmedi.")
# Out:
#      <input type="file" id="files-017edfd0-fa4b-4646-8647-74cef2a36c34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-017edfd0-fa4b-4646-8647-74cef2a36c34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# List the contents of your Google Drive's root folder
# This will show you the folders and files directly under 'My Drive'
# !ls -F '/content/drive/My Drive/Colab Notebooks/'
# Out:
#  20250718.ipynb
# '2 adet Tarama v1.ipynb'
#  3-6-10-34Kombin.ipynb
# '999_En_iyi_10_Tarama_ve_Mum_Formasyonları_TKEli.ipynb adlı not defterinin kopyası'
#  AtılımTarama.ipynb
#  Bist2CSV.ipynb
#  Bollinger_RSI_BV_Tarama
#  CizgiPatternTarama.ipynb
#  DestekDırencCokCalisanCizgiTarama.ipynb
#  DirencKirmayaYakinTarama.ipynb
# 'Direnc yukari kirilimi.ipynb'
#  Ema13Taraması.ipynb
#  Ema21Taraması.ipynb
#  Ema34Taraması.ipynb
#  Ema3-6-10vsEma34.ipynb
#  EmavsMT.ipynb
#  EnIYICizgi.ipynb
#  EniyiDestekDirencEMA.ipynb
#  Grafik_tahmin_oyunu.ipynb
#  GridTest.ipynb
#  GridTradingStrateji.ipynb
# 'GridTradingStrateji.ipynb adlı not defterinin kopyası'
#  HisseyeEniyiEmaTarama.ipynb
#  KompozitMumRenkPatternTarama.ipynb
#  KorelasyonTarama.ipynb
#  KriptoEmaTarama.ipynb
#  Luhn_algorithm.ipynb
#  MumRenkPatternTarama.ipynb
#  PatternEmaTarama.ipynb
#  PortfoyYonetim.ipynb
# 'Renkli sinyal filtreleme.ipynb'
#  RSI_Tobo_Tarama.ipynb
#  SabitKademeliGridTest.ipynb
# 'Sinyal filtreleme.ipynb'
# ...

# %%
if uploaded_file_name:
    # Define the source path of the newly uploaded file in Colab
    source_file_path = f'/content/{uploaded_file_name}'

    # Define the destination folder in your Google Drive (you can change this as needed)
    # Currently set to the root of 'My Drive'
    destination_drive_folder_for_upload = '/content/drive/My Drive/'

    # Use a shell command to copy the file
    # !cp -P "{source_file_path}" "{destination_drive_folder_for_upload}"

    print(f"Yüklenen '{uploaded_file_name}' dosyası '{destination_drive_folder_for_upload}' konumuna kopyalandı.")
else:
    print("Yüklenecek bir dosya bulunmadığı için kopyalama işlemi yapılmadı.")
# Out:
# Yüklenen 'Flaiano Ennio - 1973 - Oldurme - Flaiano Ennio.epub' dosyası '/content/drive/My Drive/' konumuna kopyalandı.
